# %%
from fractions import Fraction

# %%
Fraction(1,2) + Fraction(1,4)
# Out:
# Fraction(3, 4)

# %%
Fraction(2,3) - Fraction(1,6)
# Out:
# Fraction(1, 2)

# %%
Fraction(2,3)*2
# Out:
# Fraction(4, 3)

# %%
Fraction(2,3)/Fraction(2,3)
# Out:
# Fraction(1, 1)

# %%
Fraction(2,1) - 2
# Out:
# Fraction(0, 1)

# %%
Fraction(0,5)
# Out:
# Fraction(0, 1)

# %%
Fraction(0,5) - Fraction(0,5)
# Out:
# Fraction(0, 1)

# %%
Fraction(1,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-13-070ec78a5f59> in <module>()
# ----> 1 Fraction(1,0)
#
# C:\Users\smkim\Anaconda3\lib\fractions.py in __new__(cls, numerator, denominator, _normalize)
#     184
#     185         if denominator == 0:
# --> 186             raise ZeroDivisionError('Fraction(%s, 0)' % numerator)
#     187         if _normalize:
#     188             if type(numerator) is int is type(denominator):
#
# ZeroDivisionError: Fraction(1, 0)

# %%
Fraction(0,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-2c98765bf865> in <module>()
# ----> 1 Fraction(0,0)
#
# C:\Users\smkim\Anaconda3\lib\fractions.py in __new__(cls, numerator, denominator, _normalize)
#     184
#     185         if denominator == 0:
# --> 186             raise ZeroDivisionError('Fraction(%s, 0)' % numerator)
#     187         if _normalize:
#     188             if type(numerator) is int is type(denominator):
#
# ZeroDivisionError: Fraction(0, 0)

# %%
Fraction(4,8)
# Out:
# Fraction(1, 2)

# %%
Fraction(4,8)+Fraction(4,8)
# Out:
# Fraction(1, 1)

# %%
1+Fraction(4,8)
# Out:
# Fraction(3, 2)

# %%
Fraction(1,250000000000000000000000000) + Fraction(1,250000000000000000000000001)
# Out:
# Fraction(500000000000000000000000001, 62500000000000000000000000250000000000000000000000000)

# %%
Fraction(10,15)
# Out:
# Fraction(2, 3)

# %%
from math import gcd
gcd(1,2)
# Out:
# 1

# %%
gcd(10,-2)
# Out:
# 2

# %%
gcd(-10,-8)
# Out:
# 2

# %%
gcd(0,5)
# Out:
# 5

# %%
gcd(0,0)
# Out:
# 0
