# %%
from graphviz import Digraph

dot = Digraph(comment='The Round Table')

dot.node('A', 'King Arthur')
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

dot
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\files.pyc in _repr_svg_(self)
#      81
#      82     def _repr_svg_(self):
# ---> 83         return self.pipe(format='svg').decode(self._encoding)
#      84
#      85     def pipe(self, format=None):
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\files.pyc in pipe(self, format)
#      96         data = text_type(self.source).encode(self._encoding)
#      97
# ---> 98         outs = backend.pipe(self._engine, format, data)
#      99
#     100         return outs
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\backend.pyc in pipe(engine, format, data)
#     126             raise RuntimeError('failed to execute %r, '
#     127                 'make sure the Graphviz executables '
# --> 128                 'are on your systems\' path' % args)
#     129         else:  # pragma: no cover
#     130             raise
#
# RuntimeError: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' path

# %%
from graphviz import Digraph


dot = Digraph(comment='The Round Table')

# %%
dot
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#     342             if method is not None:
# --> 343                 return method()
#     344             return None
#     345         else:
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\files.pyc in _repr_svg_(self)
#      81
#      82     def _repr_svg_(self):
# ---> 83         return self.pipe(format='svg').decode(self._encoding)
#      84
#      85     def pipe(self, format=None):
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\files.pyc in pipe(self, format)
#      96         data = text_type(self.source).encode(self._encoding)
#      97
# ---> 98         outs = backend.pipe(self._engine, format, data)
#      99
#     100         return outs
#
# C:\Users\Semin Kim\Anaconda2\lib\site-packages\graphviz\backend.pyc in pipe(engine, format, data)
#     126             raise RuntimeError('failed to execute %r, '
#     127                 'make sure the Graphviz executables '
# --> 128                 'are on your systems\' path' % args)
#     129         else:  # pragma: no cover
#     130             raise
#
# RuntimeError: failed to execute ['dot', '-Tsvg'], make sure the Graphviz executables are on your systems' path
